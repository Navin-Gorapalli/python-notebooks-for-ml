# %%
print('Hi')
# Out:
# Hi

# %%
for i in range(1,3): #prints  1 and 2
    print(i)
# Out:
# 1
# 2

# %%
print('Hello\nWorld') #prints world in next line
# Out:
# Hello
# World

# %%
print('Hello\tWorld')  #prints world after a tab space.
# Out:
# Hello	World

# %%
print(r'Hello\nworld.Welcome \t navin') #r invalidates all escape sequences
# Out:
# Hello\nworld.Welcome \t navin

# %%
print('this is navin\'s code base') #\ is an escape seq which will nuetralize chars after it.
# Out:
# this is navin's code base

# %%
a=input('Enter any integer:')
try:
 print(int(a))
except: 
 print('Enter a valid integer')
# Out:
# Enter any integer: qwqe
# Enter a valid integer

# %%
a=input('Enter only odd numbers:')
try:
   if a%2==0:
      raise()
      print('Entering code') #after raise the next line of code does not execute.
except:
      print('Even no entered.please enter odd no')
finally:
      print('Exiting code') #after except is raised it comes to finally.even if except does not get raised finally will execute.
# Out:
# Enter only odd numbers: 4
# Even no entered.please enter odd no
# Exiting code
